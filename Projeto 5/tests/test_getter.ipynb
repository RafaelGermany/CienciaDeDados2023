# %% [markdown]
# # Módulo de busca de página - getter

# %% [markdown]
# ## Função get_web
#
# Provê uma função para buscar páginas na web com a seguinte assinatura

# %%
## Função get_web
import requests
from typing import Any
def get_web(nome_pagina: str) -> Any:
    """Esta busca páginas na web"""
    pass

# %% [markdown]
# # Treinando o uso da biblioteca Requests
#
# A referência está aqui https://requests.readthedocs.io/en/latest/user/quickstart/

# %%
r = requests.get('https://api.github.com/events')

# %%
r = requests.post('https://httpbin.org/post', data={'key': 'value'})

# %%
r = requests.get('https://api.github.com/events')
r.encoding = 'utf-8'
r.encoding
# Out:
# 'utf-8'

# %%
r.content
# Out:
# b'[{"id":"33958972022","type":"PushEvent","actor":{"id":1774901,"login":"aturnerbulldawg","display_login":"aturnerbulldawg","gravatar_id":"","url":"https://api.github.com/users/aturnerbulldawg","avatar_url":"https://avatars.githubusercontent.com/u/1774901?"},"repo":{"id":585328479,"name":"aturnerbulldawg/led-scoreboard","url":"https://api.github.com/repos/aturnerbulldawg/led-scoreboard"},"payload":{"repository_id":585328479,"push_id":16162399620,"size":1,"distinct_size":1,"ref":"refs/heads/ml","head":"0e12ce696afb875f86bcb76bf6ad1e9a7bf7fe04","before":"56ac8f9da2a2c41941becf5d379a2ac6f5173538","commits":[{"sha":"0e12ce696afb875f86bcb76bf6ad1e9a7bf7fe04","author":{"email":"andrewturner@google.com","name":"Andrew Turner"},"message":"fixing","distinct":true,"url":"https://api.github.com/repos/aturnerbulldawg/led-scoreboard/commits/0e12ce696afb875f86bcb76bf6ad1e9a7bf7fe04"}]},"public":true,"created_at":"2023-12-07T00:46:14Z"},{"id":"33958972050","type":"IssuesEvent","actor":{"id":11026246,"login":"ppoloskov","display_login":"ppoloskov","gravatar_id":"","url":"https://api.github.com/users/ppoloskov","avatar_url":"https://avatars.githubusercontent.com/u/11026246?"},"repo":{"id":604849780,"name":"aleksasiriski/rffmpeg-go","url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go/issues/26","repository_url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go","labels_url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go/issues/26/labels{/name}","comments_url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go/issues/26/comments","events_url":"https://api.github.com/repos/aleksasiriski/rffmpeg-go/issues/26/events","html_url":"https://github.com/aleksasiriski/rffmpeg-go/issues/26","id":2029640152,"node_id":"I_kwDOJA1GdM54-dnY","number":26,"title":"Getting \\"database is locked (5) (SQLITE_BUSY)\\" on fresh install","user":{"login":"ppoloskov","id":11026246,"node_id":"MDQ6VXNlcjExMDI2MjQ2","avatar_url":"https://avatars.githubusercontent.com/u/11026246?v=4","gravatar_id":"","url":"https://api.github.com/users/ppoloskov","html_url":"https://github.com/ppoloskov","followers_url":"https://api.github.com/users/ppoloskov/followers","following_url":"https://api.github.com/users/ppoloskov/following{/other_user}","gists_url":"https://api.github.com/users/ppoloskov/gists{/gist_id}","starred_url":"https://api.github.com/users/ppoloskov/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ppoloskov/subscriptions","organizations_url":"https://api.github.com/users/ppoloskov/orgs","repos_url":"https://api.github.com/users/ppoloskov/repos","events_url":"https://api.github.com/users/ppoloskov/events{/privacy}","received_events_url":"https://api.github.com/users/ppoloskov/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2023-12-07T00:46:13Z","updated_at":"2023-12-07T00:46:13Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"Kubernetes installation using `ghcr.io/aleksasiriski/jellyfin-rffmpeg`\\r\\n\\r\\nWhen running \\"ffmpeg -version\\" from the command line I always get \\"database is locked (5) (SQLITE_BUSY)\\".\\r\\n\\r\\n``` sh\\r\\n# Let\'s do a fresh run and remove databate\\r\\njellyfin@jellyfin-78667b8b4d-65g5z:~$ rm -rf  /config/rffmpeg/db/rffmpeg.db \\r\\njellyfin@jellyfin-78667b8b4d-65g5z:~$ ls -lan /config/rffmpeg/db/\\r\\ndrwxrwsr-x 2 1001 1001 4096 Dec  7 00:22 .\\r\\ndrwxrwsr-x 3 1001 1001 4096 Dec  7 00:12 ..\\r\\n\\r\\n# add host\\r\\njellyfin@jellyfin-78667b8b4d-65g5z:~$ rffmpeg add wombat\\r\\nDec  7 00:22:49 INF Database in use: sqlite\\r\\nDec  7 00:22:49 INF Succesfully added host\\r\\njellyfin@jellyfin-78667b8b4d-65g5z:~$ rffmpeg status\\r\\nDec  7 00:23:08 INF Database in use: sqlite\\r\\nDec  7 00:23:08 INF Outputting status of hosts\\r\\nServern ...

# %%
r = requests.get('https://api.github.com/events')

r.json()
# Out:
# [{'id': '33958975654',
#   'type': 'PushEvent',
#   'actor': {'id': 153067578,
#    'login': 'villanita33ensnik',
#    'display_login': 'villanita33ensnik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/villanita33ensnik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153067578?'},
#   'repo': {'id': 728096165,
#    'name': 'villanita33ensnik/filmora-crack',
#    'url': 'https://api.github.com/repos/villanita33ensnik/filmora-crack'},
#   'payload': {'repository_id': 728096165,
#    'push_id': 16162402100,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '266a17d30b1ee14e35730fe1559ea751f188dd7a',
#    'before': '1d5e2cdc9f77557fb07bd6acb78520ed8454db97',
#    'commits': [{'sha': '266a17d30b1ee14e35730fe1559ea751f188dd7a',
#      'author': {'email': '153067578+villanita33ensnik@users.noreply.github.com',
#       'name': 'villanita33ensnik'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/villanita33ensnik/filmora-crack/commits/266a17d30b1ee14e35730fe1559ea751f188dd7a'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975673',
#   'type': 'PushEvent',
#   'actor': {'id': 16258197,
#    'login': 'andry81',
#    'display_login': 'andry81',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andry81',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16258197?'},
#   'repo': {'id': 426819454,
#    'name': 'andry81-stats/bittools--gh-stats',
#    'url': 'https://api.github.com/repos/andry81-stats/bittools--gh-stats'},
#   'payload': {'repository_id': 426819454,
#    'push_id': 16162402094,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f691e272b80225ae386ad5614a3688e2ecbcc11d',
#    'before': 'fafc586a5196999eef03d743874357452dfad616',
#    'commits': [{'sha': 'f691e272b80225ae386ad5614a3688e2ecbcc11d',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'A/U: 2023-12-07T00:46Z-15T: #2150: unq all: +0 +0 -0 -0 / 0 0 | clones',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andry81-stats/bittools--gh-stats/commits/f691e272b80225ae386ad5614a3688e2ecbcc11d'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z',
#   'org': {'id': 99079148,
#    'login': 'andry81-stats',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/andry81-stats',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99079148?'}},
#  {'id': '33958975618',
#   'type': 'PushEvent',
#   'actor': {'id': 21031138,
#    'login': 'cbrzn',
#    'display_login': 'cbrzn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbrzn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21031138?'},
#   'repo': {'id': 680108746,
#    'name': 'polywrap/evo.ninja',
#    'url': 'https://api.github.com/repos/polywrap/evo.ninja'},
#   'payload': {'repository_id': 680108746,
#    'push_id': 16162402066,
#    'size': 12,
#    'distinct_size': 1,
#    'ref': 'refs/heads/namesty/ui-chat-persistence',
#    'head': 'd16608eeace16c02e968d83927146035fb102c16',
#    'before': '7f6f91305ce20732536982b223911b69f335daf1',
#    'commits': [{'sha': 'be1521582c93b9930670befffb2b5b33c2f6adf1',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': 'implemented async workspaces and now using async workspace in evo',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/be1521582c93b9930670befffb2b5b33c2f6adf1'},
#     {'sha': '3f444b0f9c53e9cd9fd9a736929e3443a661863b',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': 'updated lint version and fixed dangling promises',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/3f444b0f9c53e9cd9fd9a736929e3443a661863b'},
#     {'sha': '82c7893a63cc716a23550a40fc0180525558a4b9',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': 'fixed floating promises',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/82c7893a63cc716a23550a40fc0180525558a4b9'},
#     {'sha': '3039c089e5e9ebfe8d7bdbea06f9631749194d30',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': "Merge remote-tracking branch 'origin/dev' into nerfzael/async-workspace",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/3039c089e5e9ebfe8d7bdbea06f9631749194d30'},
#     {'sha': 'b945baeb6cf73be45ae605da5266f0d5f9a1c55a',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': 'fixed issues after merge with remote',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/b945baeb6cf73be45ae605da5266f0d5f9a1c55a'},
#     {'sha': 'b6f82cb8be12f3f1aa65ed8b7276b100d45f643a',
#      'author': {'email': 'jelli@dorg.tech', 'name': 'dOrgJelli'},
#      'message': 'chore: remove old src/scripts.ts file',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/b6f82cb8be12f3f1aa65ed8b7276b100d45f643a'},
#     {'sha': '2e0b7693aa839a674769aebd9b3955f81459c67a',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': "Merge remote-tracking branch 'origin/dev' into nerfzael/async-workspace",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/2e0b7693aa839a674769aebd9b3955f81459c67a'},
#     {'sha': '360fa7f305e13df5fc825cde761c22a1a7d44e12',
#      'author': {'email': 'bogunovij@gmail.com', 'name': 'nerfZael'},
#      'message': 'fixed floating promises and added lint to browser app',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/360fa7f305e13df5fc825cde761c22a1a7d44e12'},
#     {'sha': '7248be30dbf9acafc960cd4a9d3a5aadbb235115',
#      'author': {'email': 'cesarbrazon10@gmail.com', 'name': 'Cesar'},
#      'message': 'chore: make `onLog` in `BrowserLoggerConfig` async',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/7248be30dbf9acafc960cd4a9d3a5aadbb235115'},
#     {'sha': 'd22d231600c70ec672f6c0d1f71f54c3e5856d83',
#      'author': {'email': 'cesarbrazon10@gmail.com', 'name': 'Cesar'},
#      'message': 'chore: merge with latest dev',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/d22d231600c70ec672f6c0d1f71f54c3e5856d83'},
#     {'sha': '598ee181ba282f66f5ad88efbf787b0a90f8b0e4',
#      'author': {'email': 'nestor09amesty@gmail.com', 'name': 'Nestor Amesty'},
#      'message': 'Merge pull request #519 from polywrap/nerfzael/async-workspace\n\nAsync workspace',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/598ee181ba282f66f5ad88efbf787b0a90f8b0e4'},
#     {'sha': 'd16608eeace16c02e968d83927146035fb102c16',
#      'author': {'email': 'cesarbrazon10@gmail.com', 'name': 'Cesar'},
#      'message': 'chore: merge with latest dev',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/polywrap/evo.ninja/commits/d16608eeace16c02e968d83927146035fb102c16'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z',
#   'org': {'id': 66859008,
#    'login': 'polywrap',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/polywrap',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66859008?'}},
#  {'id': '33958975628',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 4502793,
#    'login': 'liferay-continuous-integration',
#    'display_login': 'liferay-continuous-integration',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/liferay-continuous-integration',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4502793?'},
#   'repo': {'id': 102626423,
#    'name': 'joshchong/liferay-portal',
#    'url': 'https://api.github.com/repos/joshchong/liferay-portal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828',
#     'repository_url': 'https://api.github.com/repos/joshchong/liferay-portal',
#     'labels_url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828/comments',
#     'events_url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828/events',
#     'html_url': 'https://github.com/joshchong/liferay-portal/pull/828',
#     'id': 1993893097,
#     'node_id': 'PR_kwDOBh30d85feOOd',
#     'number': 828,
#     'title': 'OpenSearch Development Testing',
#     'user': {'login': 'joshchong',
#      'id': 14988026,
#      'node_id': 'MDQ6VXNlcjE0OTg4MDI2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/14988026?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/joshchong',
#      'html_url': 'https://github.com/joshchong',
#      'followers_url': 'https://api.github.com/users/joshchong/followers',
#      'following_url': 'https://api.github.com/users/joshchong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/joshchong/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/joshchong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/joshchong/subscriptions',
#      'organizations_url': 'https://api.github.com/users/joshchong/orgs',
#      'repos_url': 'https://api.github.com/users/joshchong/repos',
#      'events_url': 'https://api.github.com/users/joshchong/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/joshchong/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1620799192,
#       'node_id': 'MDU6TGFiZWwxNjIwNzk5MTky',
#       'url': 'https://api.github.com/repos/joshchong/liferay-portal/labels/ci:test:bundle%20%20-%20success',
#       'name': 'ci:test:bundle  - success',
#       'color': 'c7e8cb',
#       'default': False,
#       'description': None},
#      {'id': 5964873572,
#       'node_id': 'LA_kwDOBh30d88AAAABY4i_ZA',
#       'url': 'https://api.github.com/repos/joshchong/liferay-portal/labels/ci:test:search-opensearch%20%20-%20failure',
#       'name': 'ci:test:search-opensearch  - failure',
#       'color': 'fccdcc',
#       'default': False,
#       'description': None},
#      {'id': 6236824798,
#       'node_id': 'LA_kwDOBh30d88AAAABc75k3g',
#       'url': 'https://api.github.com/repos/joshchong/liferay-portal/labels/ci:test:search-opensearch-simple%20%20-%20failure',
#       'name': 'ci:test:search-opensearch-simple  - failure',
#       'color': 'fccdcc',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 65,
#     'created_at': '2023-11-15T02:06:09Z',
#     'updated_at': '2023-12-07T00:46:25Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/joshchong/liferay-portal/pulls/828',
#      'html_url': 'https://github.com/joshchong/liferay-portal/pull/828',
#      'diff_url': 'https://github.com/joshchong/liferay-portal/pull/828.diff',
#      'patch_url': 'https://github.com/joshchong/liferay-portal/pull/828.patch',
#      'merged_at': None},
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/comments/1843950261',
#     'html_url': 'https://github.com/joshchong/liferay-portal/pull/828#issuecomment-1843950261',
#     'issue_url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/828',
#     'id': 1843950261,
#     'node_id': 'IC_kwDOBh30d85t6HK1',
#     'user': {'login': 'liferay-continuous-integration',
#      'id': 4502793,
#      'node_id': 'MDQ6VXNlcjQ1MDI3OTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4502793?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/liferay-continuous-integration',
#      'html_url': 'https://github.com/liferay-continuous-integration',
#      'followers_url': 'https://api.github.com/users/liferay-continuous-integration/followers',
#      'following_url': 'https://api.github.com/users/liferay-continuous-integration/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/liferay-continuous-integration/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/liferay-continuous-integration/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/liferay-continuous-integration/subscriptions',
#      'organizations_url': 'https://api.github.com/users/liferay-continuous-integration/orgs',
#      'repos_url': 'https://api.github.com/users/liferay-continuous-integration/repos',
#      'events_url': 'https://api.github.com/users/liferay-continuous-integration/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/liferay-continuous-integration/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-12-07T00:46:24Z',
#     'updated_at': '2023-12-07T00:46:24Z',
#     'author_association': 'COLLABORATOR',
#     'body': '<div><div><strong>Jenkins Build:</strong><span></span><a href="https://test-1-29.liferay.com/job/test-portal-acceptance-pullrequest(master)/8863/">test-portal-acceptance-pullrequest(master)#8863</a><br/></div><div><strong>Jenkins Report:</strong><span></span><a href="https://test-1-29.liferay.com/userContent/jobs/test-portal-acceptance-pullrequest(master)/builds/8863/jenkins-report.html">jenkins-report.html</a><br/></div><div><strong>Jenkins Suite:</strong><span></span>search-opensearch<br/></div><div><strong>Pull Request:</strong><span></span><a href="https://github.com/joshchong/liferay-portal/pull/828">joshchong#828</a><br/></div><div><strong>Testray Routine:</strong><span></span><a href="https://testray.liferay.com/home/-/testray/builds?testrayRoutineId=1306753894">EE Pull Request</a><br/></div><div><strong>Testray Build:</strong><span></span><a href="https://testray.liferay.com/home/-/testray/runs?testrayBuildId=2471647955">[master] ci:test:search-opensearch - joshchong &gt; joshchong - PR#828 - 2023-12-06[14:13:36]</a><br/></div><div><strong>Testray Importer:</strong><span></span><a href="https://test-1-29.liferay.com/job/publish-testray-report/19603/">publish-testray-report#19603</a><br/></div></div>',
#     'reactions': {'url': 'https://api.github.com/repos/joshchong/liferay-portal/issues/comments/1843950261/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975649',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 137343274,
#    'login': 'waynecharr',
#    'display_login': 'waynecharr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/waynecharr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?'},
#   'repo': {'id': 725817095,
#    'name': 'waynecharr/Grandmas_Cookies',
#    'url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies'},
#   'payload': {'action': 'closed',
#    'number': 13,
#    'pull_request': {'url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13',
#     'id': 1633481532,
#     'node_id': 'PR_kwDOK0MXB85hXPM8',
#     'html_url': 'https://github.com/waynecharr/Grandmas_Cookies/pull/13',
#     'diff_url': 'https://github.com/waynecharr/Grandmas_Cookies/pull/13.diff',
#     'patch_url': 'https://github.com/waynecharr/Grandmas_Cookies/pull/13.patch',
#     'issue_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/13',
#     'number': 13,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Pages folder in client',
#     'user': {'login': 'alycioe',
#      'id': 136280748,
#      'node_id': 'U_kgDOCB96rA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/136280748?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alycioe',
#      'html_url': 'https://github.com/alycioe',
#      'followers_url': 'https://api.github.com/users/alycioe/followers',
#      'following_url': 'https://api.github.com/users/alycioe/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alycioe/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alycioe/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alycioe/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alycioe/orgs',
#      'repos_url': 'https://api.github.com/users/alycioe/repos',
#      'events_url': 'https://api.github.com/users/alycioe/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alycioe/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "AvailableCookies - the page for buying cookies,\r\nCheckoutCart - Cart Checkout\r\nGrandmasPage - Grandma's Welcome Page!!",
#     'created_at': '2023-12-07T00:43:23Z',
#     'updated_at': '2023-12-07T00:46:24Z',
#     'closed_at': '2023-12-07T00:46:24Z',
#     'merged_at': '2023-12-07T00:46:24Z',
#     'merge_commit_sha': '5fd98ae807ca13dc03ab034af79724187f34bb84',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13/commits',
#     'review_comments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13/comments',
#     'review_comment_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/13/comments',
#     'statuses_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/statuses/b9f20825941130333e62cbe0aa7269f13a8c6541',
#     'head': {'label': 'waynecharr:page-imports',
#      'ref': 'page-imports',
#      'sha': 'b9f20825941130333e62cbe0aa7269f13a8c6541',
#      'user': {'login': 'waynecharr',
#       'id': 137343274,
#       'node_id': 'U_kgDOCC-xKg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/waynecharr',
#       'html_url': 'https://github.com/waynecharr',
#       'followers_url': 'https://api.github.com/users/waynecharr/followers',
#       'following_url': 'https://api.github.com/users/waynecharr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/waynecharr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/waynecharr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/waynecharr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/waynecharr/orgs',
#       'repos_url': 'https://api.github.com/users/waynecharr/repos',
#       'events_url': 'https://api.github.com/users/waynecharr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/waynecharr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 725817095,
#       'node_id': 'R_kgDOK0MXBw',
#       'name': 'Grandmas_Cookies',
#       'full_name': 'waynecharr/Grandmas_Cookies',
#       'private': False,
#       'owner': {'login': 'waynecharr',
#        'id': 137343274,
#        'node_id': 'U_kgDOCC-xKg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/waynecharr',
#        'html_url': 'https://github.com/waynecharr',
#        'followers_url': 'https://api.github.com/users/waynecharr/followers',
#        'following_url': 'https://api.github.com/users/waynecharr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/waynecharr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/waynecharr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/waynecharr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/waynecharr/orgs',
#        'repos_url': 'https://api.github.com/users/waynecharr/repos',
#        'events_url': 'https://api.github.com/users/waynecharr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/waynecharr/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/waynecharr/Grandmas_Cookies',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies',
#       'forks_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/forks',
#       'keys_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/teams',
#       'hooks_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/hooks',
#       'issue_events_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/events',
#       'assignees_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/tags',
#       'blobs_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/languages',
#       'stargazers_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/stargazers',
#       'contributors_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/contributors',
#       'subscribers_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/subscribers',
#       'subscription_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/subscription',
#       'commits_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/merges',
#       'archive_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/downloads',
#       'issues_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/deployments',
#       'created_at': '2023-11-30T23:41:46Z',
#       'updated_at': '2023-12-04T23:32:40Z',
#       'pushed_at': '2023-12-07T00:46:24Z',
#       'git_url': 'git://github.com/waynecharr/Grandmas_Cookies.git',
#       'ssh_url': 'git@github.com:waynecharr/Grandmas_Cookies.git',
#       'clone_url': 'https://github.com/waynecharr/Grandmas_Cookies.git',
#       'svn_url': 'https://github.com/waynecharr/Grandmas_Cookies',
#       'homepage': None,
#       'size': 153,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     'base': {'label': 'waynecharr:main',
#      'ref': 'main',
#      'sha': 'eae4fddcec1687ca8a8725a33a176f63841aeb2a',
#      'user': {'login': 'waynecharr',
#       'id': 137343274,
#       'node_id': 'U_kgDOCC-xKg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/waynecharr',
#       'html_url': 'https://github.com/waynecharr',
#       'followers_url': 'https://api.github.com/users/waynecharr/followers',
#       'following_url': 'https://api.github.com/users/waynecharr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/waynecharr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/waynecharr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/waynecharr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/waynecharr/orgs',
#       'repos_url': 'https://api.github.com/users/waynecharr/repos',
#       'events_url': 'https://api.github.com/users/waynecharr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/waynecharr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 725817095,
#       'node_id': 'R_kgDOK0MXBw',
#       'name': 'Grandmas_Cookies',
#       'full_name': 'waynecharr/Grandmas_Cookies',
#       'private': False,
#       'owner': {'login': 'waynecharr',
#        'id': 137343274,
#        'node_id': 'U_kgDOCC-xKg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/waynecharr',
#        'html_url': 'https://github.com/waynecharr',
#        'followers_url': 'https://api.github.com/users/waynecharr/followers',
#        'following_url': 'https://api.github.com/users/waynecharr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/waynecharr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/waynecharr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/waynecharr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/waynecharr/orgs',
#        'repos_url': 'https://api.github.com/users/waynecharr/repos',
#        'events_url': 'https://api.github.com/users/waynecharr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/waynecharr/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/waynecharr/Grandmas_Cookies',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies',
#       'forks_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/forks',
#       'keys_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/teams',
#       'hooks_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/hooks',
#       'issue_events_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/events',
#       'assignees_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/tags',
#       'blobs_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/languages',
#       'stargazers_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/stargazers',
#       'contributors_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/contributors',
#       'subscribers_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/subscribers',
#       'subscription_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/subscription',
#       'commits_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/merges',
#       'archive_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/downloads',
#       'issues_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/deployments',
#       'created_at': '2023-11-30T23:41:46Z',
#       'updated_at': '2023-12-04T23:32:40Z',
#       'pushed_at': '2023-12-07T00:46:24Z',
#       'git_url': 'git://github.com/waynecharr/Grandmas_Cookies.git',
#       'ssh_url': 'git@github.com:waynecharr/Grandmas_Cookies.git',
#       'clone_url': 'https://github.com/waynecharr/Grandmas_Cookies.git',
#       'svn_url': 'https://github.com/waynecharr/Grandmas_Cookies',
#       'homepage': None,
#       'size': 153,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13'},
#      'html': {'href': 'https://github.com/waynecharr/Grandmas_Cookies/pull/13'},
#      'issue': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/13'},
#      'comments': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/issues/13/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/pulls/13/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/waynecharr/Grandmas_Cookies/statuses/b9f20825941130333e62cbe0aa7269f13a8c6541'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'waynecharr',
#      'id': 137343274,
#      'node_id': 'U_kgDOCC-xKg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/137343274?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/waynecharr',
#      'html_url': 'https://github.com/waynecharr',
#      'followers_url': 'https://api.github.com/users/waynecharr/followers',
#      'following_url': 'https://api.github.com/users/waynecharr/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/waynecharr/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/waynecharr/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/waynecharr/subscriptions',
#      'organizations_url': 'https://api.github.com/users/waynecharr/orgs',
#      'repos_url': 'https://api.github.com/users/waynecharr/repos',
#      'events_url': 'https://api.github.com/users/waynecharr/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/waynecharr/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 16,
#     'deletions': 0,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975659',
#   'type': 'PushEvent',
#   'actor': {'id': 153064200,
#    'login': 'monzerotomcat578',
#    'display_login': 'monzerotomcat578',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/monzerotomcat578',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153064200?'},
#   'repo': {'id': 728079946,
#    'name': 'monzerotomcat578/hwid-spoofer',
#    'url': 'https://api.github.com/repos/monzerotomcat578/hwid-spoofer'},
#   'payload': {'repository_id': 728079946,
#    'push_id': 16162402088,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '470aa0b24932b3ac774c2b63d18eca7d4fd76a77',
#    'before': '4811bd649fdbe457fec31aaefa678fc565c8baef',
#    'commits': [{'sha': '470aa0b24932b3ac774c2b63d18eca7d4fd76a77',
#      'author': {'email': '153064200+monzerotomcat578@users.noreply.github.com',
#       'name': 'monzerotomcat578'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/monzerotomcat578/hwid-spoofer/commits/470aa0b24932b3ac774c2b63d18eca7d4fd76a77'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975643',
#   'type': 'PushEvent',
#   'actor': {'id': 143310236,
#    'login': 'jdofat',
#    'display_login': 'jdofat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jdofat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/143310236?'},
#   'repo': {'id': 728380729,
#    'name': 'jdofat/js_acme_blogs',
#    'url': 'https://api.github.com/repos/jdofat/js_acme_blogs'},
#   'payload': {'repository_id': 728380729,
#    'push_id': 16162402085,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd9fef6ff737ff1933c2896a0e6208f7d15687c93',
#    'before': '1b73203adc686e98f8590e52139c637fc2bca833',
#    'commits': [{'sha': 'd9fef6ff737ff1933c2896a0e6208f7d15687c93',
#      'author': {'email': 'j_dofat@mail.fhsu.edu', 'name': 'Jade Dofat'},
#      'message': 'm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jdofat/js_acme_blogs/commits/d9fef6ff737ff1933c2896a0e6208f7d15687c93'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975637',
#   'type': 'CreateEvent',
#   'actor': {'id': 59562158,
#    'login': 'razznblue',
#    'display_login': 'razznblue',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/razznblue',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59562158?'},
#   'repo': {'id': 728445901,
#    'name': 'razznblue/Origin-Invasion',
#    'url': 'https://api.github.com/repos/razznblue/Origin-Invasion'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'A game made with Unity utilizing the built-in terrain and timeline features',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975612',
#   'type': 'PushEvent',
#   'actor': {'id': 92332892,
#    'login': 'kevinmatthes',
#    'display_login': 'kevinmatthes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kevinmatthes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92332892?'},
#   'repo': {'id': 562492376,
#    'name': 'kevinmatthes/fortran2018-conditional-memory',
#    'url': 'https://api.github.com/repos/kevinmatthes/fortran2018-conditional-memory'},
#   'payload': {'repository_id': 562492376,
#    'push_id': 16162402068,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6c5f5def4049e2917e72ca8370150e870629ac24',
#    'before': '75b9c613b9a47376f34d1fe8ab22d71374e0f2ec',
#    'commits': [{'sha': '6c5f5def4049e2917e72ca8370150e870629ac24',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Dependabot(deps): Bump actions/setup-python from 4.8.0 to 5.0.0 (#73)\n\nBumps [actions/setup-python](https://github.com/actions/setup-python) from 4.8.0 to 5.0.0.\n- [Release notes](https://github.com/actions/setup-python/releases)\n- [Commits](https://github.com/actions/setup-python/compare/v4.8.0...v5.0.0)\n\n---\nupdated-dependencies:\n- dependency-name: actions/setup-python\n  dependency-type: direct:production\n  update-type: version-update:semver-major\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kevinmatthes/fortran2018-conditional-memory/commits/6c5f5def4049e2917e72ca8370150e870629ac24'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975586',
#   'type': 'PushEvent',
#   'actor': {'id': 98361343,
#    'login': 'JovelRamos',
#    'display_login': 'JovelRamos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JovelRamos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98361343?'},
#   'repo': {'id': 726545771,
#    'name': 'JovelRamos/rmpextension',
#    'url': 'https://api.github.com/repos/JovelRamos/rmpextension'},
#   'payload': {'repository_id': 726545771,
#    'push_id': 16162402056,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6ce11c04bdfcef75d9f780020283bec45904641c',
#    'before': 'e93a6c693d25e03b353849e4c5217a4373ba65b3',
#    'commits': [{'sha': '6ce11c04bdfcef75d9f780020283bec45904641c',
#      'author': {'email': '98361343+JovelRamos@users.noreply.github.com',
#       'name': 'JovelRamos'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JovelRamos/rmpextension/commits/6ce11c04bdfcef75d9f780020283bec45904641c'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975589',
#   'type': 'PushEvent',
#   'actor': {'id': 153097612,
#    'login': 'sumerbraumkarasik58',
#    'display_login': 'sumerbraumkarasik58',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sumerbraumkarasik58',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153097612?'},
#   'repo': {'id': 728237098,
#    'name': 'sumerbraumkarasik58/hwid-spoofer',
#    'url': 'https://api.github.com/repos/sumerbraumkarasik58/hwid-spoofer'},
#   'payload': {'repository_id': 728237098,
#    'push_id': 16162402055,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a35bc6bd956ea1720f3665813faa7e842eb187eb',
#    'before': '5b6bafb5a5db3dc58d594adbea62dfebc1bfec71',
#    'commits': [{'sha': 'a35bc6bd956ea1720f3665813faa7e842eb187eb',
#      'author': {'email': '153097612+sumerbraumkarasik58@users.noreply.github.com',
#       'name': 'sumerbraumkarasik58'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sumerbraumkarasik58/hwid-spoofer/commits/a35bc6bd956ea1720f3665813faa7e842eb187eb'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975602',
#   'type': 'PushEvent',
#   'actor': {'id': 153081478,
#    'login': 'hellbirdkillerpro86',
#    'display_login': 'hellbirdkillerpro86',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hellbirdkillerpro86',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153081478?'},
#   'repo': {'id': 728161013,
#    'name': 'hellbirdkillerpro86/Vape-V4-Cracked-by-dox',
#    'url': 'https://api.github.com/repos/hellbirdkillerpro86/Vape-V4-Cracked-by-dox'},
#   'payload': {'repository_id': 728161013,
#    'push_id': 16162402060,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '411f4d0de83fcebbe9af9281c3704295e22c341c',
#    'before': '13f8f82579e9e4df08811af360eb7cb6cc98e365',
#    'commits': [{'sha': '411f4d0de83fcebbe9af9281c3704295e22c341c',
#      'author': {'email': '153081478+hellbirdkillerpro86@users.noreply.github.com',
#       'name': 'hellbirdkillerpro86'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hellbirdkillerpro86/Vape-V4-Cracked-by-dox/commits/411f4d0de83fcebbe9af9281c3704295e22c341c'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975620',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 447912663,
#    'name': 'shelfio/fast-uslug',
#    'url': 'https://api.github.com/repos/shelfio/fast-uslug'},
#   'payload': {'ref': 'renovate/code-style-deps',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A 30x faster version of permissive slug generator that works with unicode',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z',
#   'org': {'id': 18517896,
#    'login': 'shelfio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/shelfio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18517896?'}},
#  {'id': '33958975623',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 3010904,
#    'login': 'postamar',
#    'display_login': 'postamar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/postamar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?'},
#   'repo': {'id': 283046497,
#    'name': 'airbytehq/airbyte',
#    'url': 'https://api.github.com/repos/airbytehq/airbyte'},
#   'payload': {'action': 'closed',
#    'number': 33043,
#    'pull_request': {'url': 'https://api.github.com/repos/airbytehq/airbyte/pulls/33043',
#     'id': 1628357410,
#     'node_id': 'PR_kwDOEN7yYc5hDsMi',
#     'html_url': 'https://github.com/airbytehq/airbyte/pull/33043',
#     'diff_url': 'https://github.com/airbytehq/airbyte/pull/33043.diff',
#     'patch_url': 'https://github.com/airbytehq/airbyte/pull/33043.patch',
#     'issue_url': 'https://api.github.com/repos/airbytehq/airbyte/issues/33043',
#     'number': 33043,
#     'state': 'closed',
#     'locked': False,
#     'title': ' [DNM] dind-with-tailscale test PR stack base',
#     'user': {'login': 'postamar',
#      'id': 3010904,
#      'node_id': 'MDQ6VXNlcjMwMTA5MDQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/postamar',
#      'html_url': 'https://github.com/postamar',
#      'followers_url': 'https://api.github.com/users/postamar/followers',
#      'following_url': 'https://api.github.com/users/postamar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/postamar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/postamar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/postamar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/postamar/orgs',
#      'repos_url': 'https://api.github.com/users/postamar/repos',
#      'events_url': 'https://api.github.com/users/postamar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/postamar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This PR and its children only exist to test https://github.com/airbytehq/airbyte/pull/32965',
#     'created_at': '2023-12-04T13:55:59Z',
#     'updated_at': '2023-12-07T00:46:24Z',
#     'closed_at': '2023-12-07T00:46:24Z',
#     'merged_at': None,
#     'merge_commit_sha': '8e6b4281fa02b16d338ad69bc0d868572eb06502',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [{'name': 'GL (Python)',
#       'id': 5373479,
#       'node_id': 'T_kwDOA4_XW84AUf4n',
#       'slug': 'gl-python',
#       'description': '',
#       'privacy': 'closed',
#       'notification_setting': 'notifications_enabled',
#       'url': 'https://api.github.com/organizations/59758427/team/5373479',
#       'html_url': 'https://github.com/orgs/airbytehq/teams/gl-python',
#       'members_url': 'https://api.github.com/organizations/59758427/team/5373479/members{/member}',
#       'repositories_url': 'https://api.github.com/organizations/59758427/team/5373479/repos',
#       'permission': 'pull',
#       'parent': None},
#      {'name': 'connector-operations',
#       'id': 6779212,
#       'node_id': 'T_kwDOA4_XW84AZ3FM',
#       'slug': 'connector-operations',
#       'description': 'Making connector happen.',
#       'privacy': 'closed',
#       'notification_setting': 'notifications_enabled',
#       'url': 'https://api.github.com/organizations/59758427/team/6779212',
#       'html_url': 'https://github.com/orgs/airbytehq/teams/connector-operations',
#       'members_url': 'https://api.github.com/organizations/59758427/team/6779212/members{/member}',
#       'repositories_url': 'https://api.github.com/organizations/59758427/team/6779212/repos',
#       'permission': 'pull',
#       'parent': None},
#      {'name': 'dbsources',
#       'id': 7293678,
#       'node_id': 'T_kwDOA4_XW84Ab0ru',
#       'slug': 'dbsources',
#       'description': 'Team that works on DB and DW source connectors',
#       'privacy': 'closed',
#       'notification_setting': 'notifications_enabled',
# ...
#    'login': 'THUDM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/THUDM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48590610?'}},
#  {'id': '33958975591',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 478332538,
#    'name': 'miichaels/miichaels',
#    'url': 'https://api.github.com/repos/miichaels/miichaels'},
#   'payload': {'repository_id': 478332538,
#    'push_id': 16162402062,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '963ebdce39d8d7b2363fad3df39a62548c17cda7',
#    'before': '8fa9a977bb94b7b64c890fb16ea2c877c992baf3',
#    'commits': [{'sha': '963ebdce39d8d7b2363fad3df39a62548c17cda7',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/miichaels/miichaels/commits/963ebdce39d8d7b2363fad3df39a62548c17cda7'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975571',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 233593348,
#    'name': 'SAP/cloud-sdk-js',
#    'url': 'https://api.github.com/repos/SAP/cloud-sdk-js'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/main/types/jest-29.5.11',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Use the SAP Cloud SDK for JavaScript / TypeScript to reduce development effort when building applications on SAP Business Technology Platform that communicate with SAP solutions and services such as SAP S/4HANA Cloud, SAP SuccessFactors, and many others. ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z',
#   'org': {'id': 2531208,
#    'login': 'SAP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SAP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2531208?'}},
#  {'id': '33958975603',
#   'type': 'PushEvent',
#   'actor': {'id': 3868660,
#    'login': 'Robson',
#    'display_login': 'Robson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Robson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3868660?'},
#   'repo': {'id': 594488313,
#    'name': 'Robson/ephemeral',
#    'url': 'https://api.github.com/repos/Robson/ephemeral'},
#   'payload': {'repository_id': 594488313,
#    'push_id': 16162402061,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'af2f90b77369f38c3a0b6035d0be9eb7c7e5d65d',
#    'before': '2b4b1ac23bebd4c8fd6da5eda3f2d47986a30193',
#    'commits': [{'sha': 'af2f90b77369f38c3a0b6035d0be9eb7c7e5d65d',
#      'author': {'email': 'relative@gmail.com', 'name': 'Robson'},
#      'message': 'Automated commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Robson/ephemeral/commits/af2f90b77369f38c3a0b6035d0be9eb7c7e5d65d'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975564',
#   'type': 'PushEvent',
#   'actor': {'id': 35875002,
#    'login': 'willcarpenter3',
#    'display_login': 'willcarpenter3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/willcarpenter3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35875002?'},
#   'repo': {'id': 720874909,
#    'name': 'willcarpenter3/TransfusionVR_UE5',
#    'url': 'https://api.github.com/repos/willcarpenter3/TransfusionVR_UE5'},
#   'payload': {'repository_id': 720874909,
#    'push_id': 16162402033,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/mitch/bloodvfx',
#    'head': '34d8cf7ff33316ea042100d0fb6aa8b4a24f1155',
#    'before': '764d469d3a398173d36c6ca97c68e2aa0f569444',
#    'commits': [{'sha': 'f997ef7d56a8f30741d1c111e2289621293d55e1',
#      'author': {'email': 'willcarpenter3@yahoo.com', 'name': 'Will'},
#      'message': 'Added death whistle sound cue to enemy spawn',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/willcarpenter3/TransfusionVR_UE5/commits/f997ef7d56a8f30741d1c111e2289621293d55e1'},
#     {'sha': '1d875bf8feb56094eaba05354337a4a800938fd2',
#      'author': {'email': 'willcarpenter3@yahoo.com', 'name': 'Will'},
#      'message': "Merge branch 'mitch/bloodvfx' into will/new-sounds",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/willcarpenter3/TransfusionVR_UE5/commits/1d875bf8feb56094eaba05354337a4a800938fd2'},
#     {'sha': '6c953f539c5a4a56844ee04b1f184358f41f4f62',
#      'author': {'email': 'willcarpenter3@yahoo.com', 'name': 'Will'},
#      'message': 'Altered death whistle sound, tweaks to blood orb, lightning sword',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/willcarpenter3/TransfusionVR_UE5/commits/6c953f539c5a4a56844ee04b1f184358f41f4f62'},
#     {'sha': '34d8cf7ff33316ea042100d0fb6aa8b4a24f1155',
#      'author': {'email': 'willcarpenter3@yahoo.com', 'name': 'Will'},
#      'message': "Merge branch 'will/new-sounds' into mitch/bloodvfx",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/willcarpenter3/TransfusionVR_UE5/commits/34d8cf7ff33316ea042100d0fb6aa8b4a24f1155'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975590',
#   'type': 'PushEvent',
#   'actor': {'id': 56868292,
#    'login': 'Zhytou',
#    'display_login': 'Zhytou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zhytou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56868292?'},
#   'repo': {'id': 486866465,
#    'name': 'Zhytou/Zhytou',
#    'url': 'https://api.github.com/repos/Zhytou/Zhytou'},
#   'payload': {'repository_id': 486866465,
#    'push_id': 16162402050,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5a54817aa1aaaf8767e2a31b96b8bb9e8cf5a3c8',
#    'before': 'c61c84ce5a13df8bf865f1290c16c353657878fe',
#    'commits': [{'sha': '5a54817aa1aaaf8767e2a31b96b8bb9e8cf5a3c8',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zhytou/Zhytou/commits/5a54817aa1aaaf8767e2a31b96b8bb9e8cf5a3c8'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975561',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 403351062,
#    'name': 'Gucs1/Gucs1',
#    'url': 'https://api.github.com/repos/Gucs1/Gucs1'},
#   'payload': {'repository_id': 403351062,
#    'push_id': 16162402026,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '044bf4857f0de68c6d3a2924d63a73d2c5a9deea',
#    'before': '89bc02d0294f2860737c60abd5b4cd4380bf5e0e',
#    'commits': [{'sha': '044bf4857f0de68c6d3a2924d63a73d2c5a9deea',
#      'author': {'email': 'profile-summary-cards-bot@example.com',
#       'name': 'profile-summary-cards[bot]'},
#      'message': 'Generate profile summary cards',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gucs1/Gucs1/commits/044bf4857f0de68c6d3a2924d63a73d2c5a9deea'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975557',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 656575147,
#    'name': 'graceyou950/okiekanse',
#    'url': 'https://api.github.com/repos/graceyou950/okiekanse'},
#   'payload': {'repository_id': 656575147,
#    'push_id': 16162402019,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1215a4cc6b68aa84c2b3648e0d110b09ecdf1815',
#    'before': 'b95814dcec21547425da5413a9f999b3a1fe2895',
#    'commits': [{'sha': '1215a4cc6b68aa84c2b3648e0d110b09ecdf1815',
#      'author': {'email': 'graceyou950@gmail.com', 'name': 'graceyou950'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/graceyou950/okiekanse/commits/1215a4cc6b68aa84c2b3648e0d110b09ecdf1815'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975562',
#   'type': 'PushEvent',
#   'actor': {'id': 80601826,
#    'login': 'NormallyRayne',
#    'display_login': 'NormallyRayne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NormallyRayne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80601826?'},
#   'repo': {'id': 672145229,
#    'name': 'NormallyRayne/NormallyRayne',
#    'url': 'https://api.github.com/repos/NormallyRayne/NormallyRayne'},
#   'payload': {'repository_id': 672145229,
#    'push_id': 16162402032,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f2dbe43deac4f81434d3485c29872fd49dcda79c',
#    'before': '8782d720efc2ffa4f7821e30900ab845a4a99983',
#    'commits': [{'sha': 'f2dbe43deac4f81434d3485c29872fd49dcda79c',
#      'author': {'email': 'Contact.RickCollett@protonmail.com', 'name': 'Rick'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NormallyRayne/NormallyRayne/commits/f2dbe43deac4f81434d3485c29872fd49dcda79c'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975581',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 366123808,
#    'name': 'Hao-yiwen/Hao-yiwen',
#    'url': 'https://api.github.com/repos/Hao-yiwen/Hao-yiwen'},
#   'payload': {'repository_id': 366123808,
#    'push_id': 16162402047,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '21bda28d01ca0d828c87de18dcf4ce33b43c9354',
#    'before': '37d81ea0edf0d58e55ef380ec7ecc32920b009b1',
#    'commits': [{'sha': '21bda28d01ca0d828c87de18dcf4ce33b43c9354',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Hao-yiwen/Hao-yiwen/commits/21bda28d01ca0d828c87de18dcf4ce33b43c9354'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975551',
#   'type': 'PushEvent',
#   'actor': {'id': 153097101,
#    'login': 'clearheadedsward1',
#    'display_login': 'clearheadedsward1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clearheadedsward1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153097101?'},
#   'repo': {'id': 728234627,
#    'name': 'clearheadedsward1/apex-hax',
#    'url': 'https://api.github.com/repos/clearheadedsward1/apex-hax'},
#   'payload': {'repository_id': 728234627,
#    'push_id': 16162402038,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8f347dd36073f151c2fb296660366825beeee866',
#    'before': 'bd953d735c927d20b68799b65cde44f95fc02bfe',
#    'commits': [{'sha': '8f347dd36073f151c2fb296660366825beeee866',
#      'author': {'email': '153097101+clearheadedsward1@users.noreply.github.com',
#       'name': 'clearheadedsward1'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/clearheadedsward1/apex-hax/commits/8f347dd36073f151c2fb296660366825beeee866'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975542',
#   'type': 'PushEvent',
#   'actor': {'id': 153069930,
#    'login': 'emavinnsword1992',
#    'display_login': 'emavinnsword1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emavinnsword1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153069930?'},
#   'repo': {'id': 728107693,
#    'name': 'emavinnsword1992/hwid-spoofer',
#    'url': 'https://api.github.com/repos/emavinnsword1992/hwid-spoofer'},
#   'payload': {'repository_id': 728107693,
#    'push_id': 16162402028,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '591178c1c3188482ce74fc154f0637e71651a42a',
#    'before': 'f147b744b3cfad23b4d48e9c5366303347fc125f',
#    'commits': [{'sha': '591178c1c3188482ce74fc154f0637e71651a42a',
#      'author': {'email': '153069930+emavinnsword1992@users.noreply.github.com',
#       'name': 'emavinnsword1992'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/emavinnsword1992/hwid-spoofer/commits/591178c1c3188482ce74fc154f0637e71651a42a'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975568',
#   'type': 'PushEvent',
#   'actor': {'id': 153098695,
#    'login': 'pomidorkasquiltion16',
#    'display_login': 'pomidorkasquiltion16',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pomidorkasquiltion16',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153098695?'},
#   'repo': {'id': 728241966,
#    'name': 'pomidorkasquiltion16/apex-hack-2023',
#    'url': 'https://api.github.com/repos/pomidorkasquiltion16/apex-hack-2023'},
#   'payload': {'repository_id': 728241966,
#    'push_id': 16162402041,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '12b2a4b30a55aac68e5420f7fe8491987864ec39',
#    'before': '733e0673786d2fec4530245d4179b50e5d3a25a3',
#    'commits': [{'sha': '12b2a4b30a55aac68e5420f7fe8491987864ec39',
#      'author': {'email': '153098695+pomidorkasquiltion16@users.noreply.github.com',
#       'name': 'pomidorkasquiltion16'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pomidorkasquiltion16/apex-hack-2023/commits/12b2a4b30a55aac68e5420f7fe8491987864ec39'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975572',
#   'type': 'PushEvent',
#   'actor': {'id': 153096629,
#    'login': 'mrmonster95faster',
#    'display_login': 'mrmonster95faster',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrmonster95faster',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153096629?'},
#   'repo': {'id': 728232729,
#    'name': 'mrmonster95faster/Rust-Free-Hack',
#    'url': 'https://api.github.com/repos/mrmonster95faster/Rust-Free-Hack'},
#   'payload': {'repository_id': 728232729,
#    'push_id': 16162402045,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0af57afbfd82d1da8c2db1303e35c51b167f7b79',
#    'before': '105a59f7bd7e2f28fca6836ff9c60c7f50cd9cc7',
#    'commits': [{'sha': '0af57afbfd82d1da8c2db1303e35c51b167f7b79',
#      'author': {'email': '153096629+mrmonster95faster@users.noreply.github.com',
#       'name': 'mrmonster95faster'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mrmonster95faster/Rust-Free-Hack/commits/0af57afbfd82d1da8c2db1303e35c51b167f7b79'}]},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'},
#  {'id': '33958975554',
#   'type': 'DeleteEvent',
#   'actor': {'id': 128087310,
#    'login': 'Laurry-gee',
#    'display_login': 'Laurry-gee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Laurry-gee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128087310?'},
#   'repo': {'id': 675917060,
#    'name': 'Laurry-gee/hello-world',
#    'url': 'https://api.github.com/repos/Laurry-gee/hello-world'},
#   'payload': {'ref': 'snyk-upgrade-6129e1851dde4717d186e6c281d99003',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T00:46:25Z'}]

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# b'>\x9aL\xd8,Z2]\xe7\xb3'

# %%
with open("arquivo", 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)

# %% [markdown]
# # Abrindo arquivos com Python

# %%
arquivo2 = open("arquivo2.txt", 'w')
arquivo2.close()

# %%
casa = "A casa é bonita"

# %%
arquivo_casa = open("casa.txt", 'w')

# %%
import io
arquivo_casa = io.StringIO(casa)

# %%
arquivo_casa.close()
